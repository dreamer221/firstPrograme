# %%
import numpy as np

# %% [markdown]
# # 4 利用数组进行数据处理

# %%
points = np.arange(-5, 5, 0.01)
print(type(points), points.shape)
# Out:
# <class 'numpy.ndarray'> (1000,)

# %%
xs, ys = np.meshgrid(points, points)
print(type(xs), xs.shape, xs, sep='\n')
print("=============" * 4)
print(type(ys), ys.shape, ys, sep='\n')
# Out:
# <class 'numpy.ndarray'>
# (1000, 1000)
# [[-5.   -4.99 -4.98 ...  4.97  4.98  4.99]
#  [-5.   -4.99 -4.98 ...  4.97  4.98  4.99]
#  [-5.   -4.99 -4.98 ...  4.97  4.98  4.99]
#  ...
#  [-5.   -4.99 -4.98 ...  4.97  4.98  4.99]
#  [-5.   -4.99 -4.98 ...  4.97  4.98  4.99]
#  [-5.   -4.99 -4.98 ...  4.97  4.98  4.99]]
# ====================================================
# <class 'numpy.ndarray'>
# (1000, 1000)
# [[-5.   -5.   -5.   ... -5.   -5.   -5.  ]
#  [-4.99 -4.99 -4.99 ... -4.99 -4.99 -4.99]
#  [-4.98 -4.98 -4.98 ... -4.98 -4.98 -4.98]
#  ...
#  [ 4.97  4.97  4.97 ...  4.97  4.97  4.97]
#  [ 4.98  4.98  4.98 ...  4.98  4.98  4.98]
#  [ 4.99  4.99  4.99 ...  4.99  4.99  4.99]]

# %%
import matplotlib.pyplot as plt
z = np.sqrt(xs ** 2 + ys ** 2)
plt.imshow(z)
plt.colorbar()
plt.title("image plot of $\sqrt{x^2 + y^2}$ for a grid of value")
plt.show()

# %% [markdown]
# ## 4.2 将条件逻辑表述为数组运算

# %%
xarr = np.array([1.1, 1.2, 1.3, 1.4, 1.5])
yarr = np.array([2.1, 2.2, 2.3, 2.4, 2.5])
cond = np.array([True, False, True, True, False])
result = np.where(cond, xarr, yarr)
result
# Out:
# array([1.1, 2.2, 1.3, 1.4, 2.5])

# %%
arr = np.random.randn(4, 4)
arr
# Out:
# array([[-0.54187895, -1.18482143, -0.89909132,  0.20722017],
#        [ 0.4360661 ,  0.33125372,  0.22515482, -1.18170072],
#        [ 0.75898099, -0.1526495 ,  0.10644687, -1.59814969],
#        [-2.26527662,  1.27368963,  0.92303286,  0.68276337]])

# %%
# 把所有的正数变为2，所有的负数变为-2
np.where(arr > 0, 2, -2)
# Out:
# array([[-2, -2, -2,  2],
#        [ 2,  2,  2, -2],
#        [ 2, -2,  2, -2],
#        [-2,  2,  2,  2]])

# %%
# 把整数变为2，其他仍未原来的数
np.where(arr > 0, 2, arr)
# Out:
# array([[-0.54187895, -1.18482143, -0.89909132,  2.        ],
#        [ 2.        ,  2.        ,  2.        , -1.18170072],
#        [ 2.        , -0.1526495 ,  2.        , -1.59814969],
#        [-2.26527662,  2.        ,  2.        ,  2.        ]])
